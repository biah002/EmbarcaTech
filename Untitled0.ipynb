# %% [markdown]
# <a href="https://colab.research.google.com/github/biah002/EmbarcaTech/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, IoT! o ambiente está configurado.")
# Out:
# Olá, IoT! o ambiente está configurado.
